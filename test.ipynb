# %%
import torch
import pandas as pd
import numpy as np
from w1ot.data import make_2d_data, plot_2d_data

# %%
data = pd.read_csv('./moons_1.csv')
source = data[['source_x', 'source_y']].values
target = data[['target_x', 'target_y']].values
transported = data[['transported_x', 'transported_y']].values
plot_2d_data(source, target, transported)

# %%
data = pd.read_csv('./s_curve_1.csv')
source = data[['source_x', 'source_y']].values
target = data[['target_x', 'target_y']].values
transported = data[['transported_x', 'transported_y']].values
plot_2d_data(source, target, transported)

# %%
data = pd.read_csv('./swiss_roll.csv')
source = data[['source_x', 'source_y']].values
target = data[['target_x', 'target_y']].values
transported = data[['transported_x', 'transported_y']].values
plot_2d_data(source, target, transported)

# %%
data = pd.read_csv('./circles.csv')
source = data[['source_x', 'source_y']].values
target = data[['target_x', 'target_y']].values
transported = data[['transported_x', 'transported_y']].values
plot_2d_data(source, target, transported)

# %%
data = pd.read_csv('./checkerboard.csv')
source = data[['source_x', 'source_y']].values
target = data[['target_x', 'target_y']].values
transported = data[['transported_x', 'transported_y']].values
plot_2d_data(source, target, transported)

# %%
data = pd.read_csv('./8gaussians.csv')
source = data[['source_x', 'source_y']].values
target = data[['target_x', 'target_y']].values
transported = data[['transported_x', 'transported_y']].values
plot_2d_data(source, target, transported)
