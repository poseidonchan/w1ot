# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statannotations.Annotator import Annotator

# %%
data = pd.read_csv('./iid_results.csv', index_col=None, header=0)

# %%
data_4i = data[data.dataset_name == '4i-melanoma-8h-48']
data_sciplex50 = data[data.dataset_name == 'sciplex3-hvg-top1k_50']
data_sciplex = data[data.dataset_name == 'sciplex3-hvg-top1k']

# %%
add_data = pd.read_csv('./iid_cpabiolord.csv', index_col=None, header=0)

# %%
new_modelname = []
for name in add_data['model']:
    if name == "simplified_chemcpa":
        new_modelname.append("cpa")
    else:
        new_modelname.append(name)
add_data['model'] = new_modelname

# %%
add_data_4i = add_data[add_data.dataset_name == '4i-melanoma-8h-48']
add_data_sciplex50 = add_data[add_data.dataset_name == 'sciplex3-hvg-top1k_50']

# %%
data_4i = pd.concat([add_data_4i, data_4i])

# %%
data_sciplex50 = pd.concat([add_data_sciplex50, data_sciplex50])

# %%
data_sciplex = pd.concat([add_data_sciplex50, data_sciplex])

# %%
colormap = {
    'w1ot': '#51A9D6',
    'w2ot': '#E05732',
    'scgen': '#7C7379',
    'cpa': '#3D5467',
    'biolord': '#FFE19C',
    'identity': '#C5BEBE',
    'observed': '#9FA6C3'
}

order = ['w1ot', 'w2ot', 'scgen', 'biolord', 'cpa', 'observed', 'identity']

# %%
# Create subplots: 1 row, 3 columns for the three metrics
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Define the pairs to compare
pairs = [("w1ot", "scgen"), ("w1ot", "w2ot"), ("w1ot", "cpa"), ("w1ot", "biolord")]

# Plot for "cell_r2"
ax0 = sns.barplot(ax=axes[0], x='model', y='cell_r2', data=data_4i, palette=colormap, order=order)
annotator2 = Annotator(ax0, pairs, data=data_4i, x='model', y='cell_r2', order=order)
annotator2.configure(test='Mann-Whitney', text_format='star', loc='outside',fontsize=16)
annotator2.apply_and_annotate()
axes[0].set_title(r"$r^2$",fontsize=20)  # LaTeX for R^2
axes[0].set(xlabel=None, ylabel=None)  # Remove labels
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].tick_params(axis='both', labelsize=12)
# Plot for "cell_l2"
ax1 = sns.barplot(ax=axes[1], x='model', y='cell_l2', data=data_4i, palette=colormap, order=order)
annotator3 = Annotator(ax1, pairs, data=data_4i, x='model', y='cell_l2', order=order)
annotator3.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator3.apply_and_annotate()
axes[1].set_title(r"$l_2$",fontsize=20)  # LaTeX for R^2
axes[1].set(xlabel=None, ylabel=None)  # Remove labels
axes[1].spines['top'].set_visible(False)
axes[1].spines['right'].set_visible(False)
axes[1].tick_params(axis='both', labelsize=12)

# Plot for "cell_mmd"
axes[2].set_yscale('log')
ax2 = sns.barplot(ax=axes[2], x='model', y='cell_mmd', data=data_4i, palette=colormap, order=order)

annotator1 = Annotator(ax2, pairs, data=data_4i, x='model', y='cell_mmd', order=order)
annotator1.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator1.apply_and_annotate()
axes[2].set_title("MMD",fontsize=20)
axes[2].set(xlabel=None, ylabel=None)  # Remove labels
axes[2].spines['top'].set_visible(False)
axes[2].spines['right'].set_visible(False)
axes[2].tick_params(axis='both', labelsize=12)

# Adjust layout to make sure titles and labels do not overlap
plt.tight_layout()
plt.subplots_adjust(top=0.7)
plt.suptitle("4i", fontsize=24)
plt.savefig('./4i.png', format='png', dpi=300)
# Show the final plot
plt.show()
# Out:
# /var/folders/js/g7pncpj135j12v52t38tgclh0000gn/T/ipykernel_58344/2647090147.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax0 = sns.barplot(ax=axes[0], x='model', y='cell_r2', data=data_4i, palette=colormap, order=order)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# w1ot vs. w2ot: Mann-Whitney-Wilcoxon test two-sided, P_val:3.806e-01 U_stat=1.621e+04
# w1ot vs. scgen: Mann-Whitney-Wilcoxon test two-sided, P_val:1.092e-16 U_stat=2.564e+04
# w1ot vs. biolord: Mann-Whitney-Wilcoxon test two-sided, P_val:1.088e-05 U_stat=2.164e+04
# w1ot vs. cpa: Mann-Whitney-Wilcoxon test two-sided, P_val:5.173e-62 U_stat=3.421e+04
# ...

# %%
colormap = {
    'w1ot': '#51A9D6',
    'w2ot': '#E05732',
    'scgen': '#7C7379',
    'cpa': '#3D5467',
    'biolord': '#FFE19C',
    'identity': '#C5BEBE',
    'observed': '#9FA6C3'
}

order = ['w1ot', 'w2ot', 'scgen', 'biolord', 'cpa', 'observed', 'identity']

# %%
# Create subplots: 1 row, 3 columns for the three metrics
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Define the pairs to compare
pairs = [("w1ot", "scgen"), ("w1ot", "w2ot"), ("w1ot", "cpa"), ("w1ot", "biolord")]

# Plot for "cell_r2"
ax0 = sns.barplot(ax=axes[0], x='model', y='cell_r2', data=data_sciplex50, palette=colormap, order=order)
annotator2 = Annotator(ax0, pairs, data=data_sciplex50, x='model', y='cell_r2', order=order)
annotator2.configure(test='Mann-Whitney', text_format='star', loc='outside',fontsize=16)
annotator2.apply_and_annotate()
axes[0].set_title(r"$r^2$",fontsize=20)  # LaTeX for R^2
axes[0].set(xlabel=None, ylabel=None)  # Remove labels
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].tick_params(axis='both', labelsize=12)
# Plot for "cell_l2"
ax1 = sns.barplot(ax=axes[1], x='model', y='cell_l2', data=data_sciplex50, palette=colormap, order=order)
annotator3 = Annotator(ax1, pairs, data=data_sciplex50, x='model', y='cell_l2', order=order)
annotator3.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator3.apply_and_annotate()
axes[1].set_title(r"$l_2$",fontsize=20)  # LaTeX for L_2
axes[1].set(xlabel=None, ylabel=None)  # Remove labels
axes[1].spines['top'].set_visible(False)
axes[1].spines['right'].set_visible(False)
axes[1].tick_params(axis='both', labelsize=12)
# Plot for "cell_mmd"
ax2 = sns.barplot(ax=axes[2], x='model', y='cell_mmd', data=data_sciplex50, palette=colormap, order=order)
axes[2].set_yscale('log')
annotator1 = Annotator(ax2, pairs, data=data_sciplex50, x='model', y='cell_mmd', order=order)
annotator1.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator1.apply_and_annotate()

axes[2].set_title("MMD",fontsize=20)
axes[2].set(xlabel=None, ylabel=None)  # Remove labels
axes[2].spines['top'].set_visible(False)
axes[2].spines['right'].set_visible(False)
axes[2].tick_params(axis='both', labelsize=12)
# Adjust layout to make sure titles and labels do not overlap
plt.tight_layout()
plt.subplots_adjust(top=0.7)
plt.suptitle("sciplex3-AE", fontsize=24)
plt.savefig('./sciplex3-AE.png', format='png', dpi=300)
# Show the final plot
plt.show()
# Out:
# /var/folders/js/g7pncpj135j12v52t38tgclh0000gn/T/ipykernel_58344/1325364135.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax0 = sns.barplot(ax=axes[0], x='model', y='cell_r2', data=data_sciplex50, palette=colormap, order=order)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# w1ot vs. w2ot: Mann-Whitney-Wilcoxon test two-sided, P_val:8.493e-05 U_stat=5.250e+02
# w1ot vs. scgen: Mann-Whitney-Wilcoxon test two-sided, P_val:1.942e-03 U_stat=1.397e+03
# w1ot vs. biolord: Mann-Whitney-Wilcoxon test two-sided, P_val:6.206e-03 U_stat=6.730e+02
# w1ot vs. cpa: Mann-Whitney-Wilcoxon test two-sided, P_val:1.574e-06 U_stat=1.608e+03
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

# Data for first plot
dimensions = [2, 2, 10, 10, 50, 50, 250, 250, 1250, 1250]
methods = ['w1ot', 'w2ot', 'w1ot', 'w2ot', 'w1ot', 'w2ot', 'w1ot', 'w2ot', 'w1ot', 'w2ot']
times = [173, 456, 182, 465, 189, 497, 203, 645, 259, 1124]

colormap = {
    'w1ot': '#51A9D6',
    'w2ot': '#E05732',
    'scgen': '#7C7379',
    'cpa': '#3D5467',
    'biolord': '#FFE19C',
    'identity': '#C5BEBE',
    'observed': '#9FA6C3'
}

# Define the pairs to compare
pairs = [("w1ot", "scgen"), ("w1ot", "w2ot"), ("w1ot", "cpa"), ("w1ot", "biolord")]

# Set up the figure and axes
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# First plot: Line plot for scalability comparison
ax = axes[0]
ax.plot([d for d, m in zip(dimensions, methods) if m == 'w1ot'], [t for t, m in zip(times, methods) if m == 'w1ot'],
        marker='o', color=colormap['w1ot'], label='w1ot')
ax.plot([d for d, m in zip(dimensions, methods) if m == 'w2ot'], [t for t, m in zip(times, methods) if m == 'w2ot'],
        marker='o', color=colormap['w2ot'], label='w2ot')
ax.set_yscale('log')
ax.set_xlabel('Data Dimension', fontsize=20)
ax.set_ylabel('Seconds (log scale)', fontsize=20)
ax.set_title('Time consumption for 10000 iterations', fontsize=20)
ax.legend(fontsize=16)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set xticks and yticks fontsize for the first plot
ax.tick_params(axis='both', labelsize=12)

# Second plot: Bar plot for "cell_r2"
ax1 = sns.barplot(ax=axes[1], x='model', y='cell_r2', data=data_sciplex, palette=colormap, order=order)
annotator2 = Annotator(ax1, pairs, data=data_sciplex, x='model', y='cell_r2', order=order)
annotator2.configure(test='Mann-Whitney', text_format='star', loc='inside', fontsize=16)
annotator2.apply_and_annotate()
axes[1].set_title(r"$r^2$", fontsize=20)
axes[1].set(xlabel=None, ylabel=None)  # Remove labels
axes[1].spines['top'].set_visible(False)
axes[1].spines['right'].set_visible(False)

# Set xticks and yticks fontsize for the second plot
axes[1].tick_params(axis='both', labelsize=12)

# Third plot: Bar plot for "cell_mmd"
ax2 = sns.barplot(ax=axes[2], x='model', y='cell_mmd', data=data_sciplex, palette=colormap, order=order)
axes[2].set_yscale('log')
annotator1 = Annotator(ax2, pairs, data=data_sciplex, x='model', y='cell_mmd', order=order)
annotator1.configure(test='Mann-Whitney', text_format='star', loc='inside', fontsize=16)
annotator1.apply_and_annotate()
axes[2].set_title("MMD", fontsize=20)
axes[2].set(xlabel=None, ylabel=None)  # Remove labels
axes[2].spines['top'].set_visible(False)
axes[2].spines['right'].set_visible(False)

# Set xticks and yticks fontsize for the third plot
axes[2].tick_params(axis='both', labelsize=12)

# Set the common title
plt.suptitle("sciplex3", fontsize=24, x=0.66)

# Adjust layout and save the figure as an EPS file
plt.tight_layout()
plt.savefig('comparison_plots.png', format='png', dpi=300)

# Show the plot
plt.show()
# Out:
# /var/folders/js/g7pncpj135j12v52t38tgclh0000gn/T/ipykernel_58344/645243339.py:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.barplot(ax=axes[1], x='model', y='cell_r2', data=data_sciplex, palette=colormap, order=order)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# w1ot vs. w2ot: Mann-Whitney-Wilcoxon test two-sided, P_val:4.896e-09 U_stat=1.738e+03
# w1ot vs. scgen: Mann-Whitney-Wilcoxon test two-sided, P_val:1.334e-01 U_stat=1.199e+03
# w1ot vs. biolord: Mann-Whitney-Wilcoxon test two-sided, P_val:1.002e-02 U_stat=6.930e+02
# w1ot vs. cpa: Mann-Whitney-Wilcoxon test two-sided, P_val:3.999e-05 U_stat=1.522e+03
# ...

# %%
ood_data = pd.read_csv('./ood_results.csv', index_col=None, header=0)

# %%
new_modelname = []
for name in ood_data['model']:
    if name == "simplified_chemcpa":
        new_modelname.append("cpa")
    else:
        new_modelname.append(name)
ood_data['model'] = new_modelname

# %%
colormap = {
    'w1ot': '#51A9D6',
    'w2ot': '#E05732',
    'scgen': '#7C7379',
    'cpa': '#3D5467',
    'biolord': '#FFE19C',
}
order = ['w1ot', 'w2ot', 'scgen', 'biolord', 'cpa']

# %%
# Create subplots: 1 row, 3 columns for the three metrics
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Define the pairs to compare
pairs = [("w1ot", "scgen"), ("w1ot", "w2ot"), ("w1ot", "cpa"), ("w1ot", "biolord")]

# Plot for "cell_r2"
ax0 = sns.barplot(ax=axes[0], x='model', y='cell_r2', data=ood_data, palette=colormap, order=order)
annotator2 = Annotator(ax0, pairs, data=ood_data, x='model', y='cell_r2', order=order)
annotator2.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator2.apply_and_annotate()
axes[0].set_title(r"$r^2$",fontsize=20)  # LaTeX for R^2
axes[0].set(xlabel=None, ylabel=None)  # Remove labels
axes[0].spines['top'].set_visible(False)
axes[0].spines['right'].set_visible(False)
axes[0].tick_params(axis='both', labelsize=12)
# Plot for "cell_l2"
ax1 = sns.barplot(ax=axes[1], x='model', y='cell_l2', data=ood_data, palette=colormap, order=order)
annotator3 = Annotator(ax1, pairs, data=ood_data, x='model', y='cell_l2', order=order)
annotator3.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator3.apply_and_annotate()
axes[1].set_title(r"$l_2$",fontsize=20)  # LaTeX for L_2
axes[1].set(xlabel=None, ylabel=None)  # Remove labels
axes[1].spines['top'].set_visible(False)
axes[1].spines['right'].set_visible(False)
axes[1].tick_params(axis='both', labelsize=12)
# Plot for "cell_mmd"
ax2 = sns.barplot(ax=axes[2], x='model', y='cell_mmd', data=ood_data, palette=colormap, order=order)
axes[2].set_yscale('log')
annotator1 = Annotator(ax2, pairs, data=ood_data, x='model', y='cell_mmd', order=order)
annotator1.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator1.apply_and_annotate()

axes[2].set_title("MMD",fontsize=20)
axes[2].set(xlabel=None, ylabel=None)  # Remove labels
axes[2].spines['top'].set_visible(False)
axes[2].spines['right'].set_visible(False)
axes[2].tick_params(axis='both', labelsize=12)
# Adjust layout to make sure titles and labels do not overlap
plt.tight_layout()
plt.subplots_adjust(top=0.85) 
plt.suptitle("unseen celltype sciplex3-AE", fontsize=24)
plt.savefig('./ood_sciplex3-AE.png', format='png', dpi=300)
# Show the final plot
plt.show()
# Out:
# /var/folders/js/g7pncpj135j12v52t38tgclh0000gn/T/ipykernel_58344/363429129.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax0 = sns.barplot(ax=axes[0], x='model', y='cell_r2', data=ood_data, palette=colormap, order=order)
# /var/folders/js/g7pncpj135j12v52t38tgclh0000gn/T/ipykernel_58344/363429129.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax1 = sns.barplot(ax=axes[1], x='model', y='cell_l2', data=ood_data, palette=colormap, order=order)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# ...

# %%
data = pd.read_csv('./gene_perturb_results.csv', index_col=None, header=0)

# %%
new_modelname = []
for name in data['model']:
    if name == "simplified_chemcpa":
        new_modelname.append("cpa")
    else:
        new_modelname.append(name)
data['model'] = new_modelname

# %%
colormap = {
    'w1ot': '#51A9D6',
    'w2ot': '#E05732',
    'scgen': '#7C7379',
    'cpa': '#3D5467',
    'biolord': '#FFE19C',
}
order = ['w1ot', 'w2ot', 'scgen', 'biolord', 'cpa']

# %%
data.columns
# Out:
# Index(['model', 'dataset_name', 'perturbation', 'latent_dim', 'logfc_error',
#        'logfc_corr', 'logfc_r2', 'direction_accuracy', 'num_perturbed_genes',
#        'perturbed_genes', 'fold_change', 'experiment_type'],
#       dtype='object')

# %%
# Create subplots: 1 row, 3 columns for the three metrics
fig, ax = plt.subplots(1, 1, figsize=(6, 6))

# Plot for "cell_r2"
ax0 = sns.barplot(ax=ax, x='model', y='logfc_error', data=data, palette=colormap, order=order)
annotator2 = Annotator(ax0, pairs, data=data, x='model', y='logfc_error', order=order)
annotator2.configure(test='Mann-Whitney', text_format='star', loc='inside',fontsize=16)
annotator2.apply_and_annotate()
ax.set_title(r"$MAE$",fontsize=20)  # LaTeX for R^2
ax.set(xlabel=None, ylabel=None)  # Remove labels
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='both', labelsize=12)

plt.tight_layout()
plt.subplots_adjust(top=0.85) 
plt.suptitle("LogFC error of 5 perturbed feature", fontsize=24)
plt.savefig('./gene_perturb.png', format='png', dpi=300)
# Show the final plot
plt.show()
# Out:
# /var/folders/js/g7pncpj135j12v52t38tgclh0000gn/T/ipykernel_58344/1849996155.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax0 = sns.barplot(ax=ax, x='model', y='logfc_error', data=data, palette=colormap, order=order)
# p-value annotation legend:
#       ns: 5.00e-02 < p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# w1ot vs. w2ot: Mann-Whitney-Wilcoxon test two-sided, P_val:2.222e-01 U_stat=6.000e+00
# w1ot vs. scgen: Mann-Whitney-Wilcoxon test two-sided, P_val:7.937e-03 U_stat=0.000e+00
# w1ot vs. biolord: Mann-Whitney-Wilcoxon test two-sided, P_val:7.937e-03 U_stat=0.000e+00
# w1ot vs. cpa: Mann-Whitney-Wilcoxon test two-sided, P_val:7.937e-03 U_stat=0.000e+00
